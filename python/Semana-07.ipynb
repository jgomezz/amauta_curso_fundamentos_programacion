# %% [markdown]
# # **Laboratorio 07 : Diccionarios**

# %% [markdown]
# # 1.- Introducción
# El nuevo tipo de "estructura de datos" que veremos son los "diccionarios".  Entre sus caracteristicas es que permite guardar datos que son asociados a una clave, lo cual nos permite encontrar rápidadmente los datos, como se entiende las llaves son similares a los índices de un libro y los valores serian los contenidos de los capítulos del libro.
#
# Los Diccionarios se crean usando claves de la siguiente manera:
#
# > a = **{** $ clave{1} : valor_{1}, clave_{2}: valor_{2}, clave_{3} : valor_{3},\dots $ **}**
#
# Se puede notar que los "**:**" permiten separar las claves de los datos.

# %%
numeros1 = (1,2,3,4)   # Tupla --> No se puede cambiar los valores
numeros2 = [1,2,3,4]   # Lista --> Si se puede cambiar los valores
numeros3 = {1,2,3,4}   # Set.  --> No permite datos repetidos y se pueden cambiar

# Definición de un diicionario empleando números como clave
numeros4 = {1:10,2:20,3:30}  # Diccionario.
print(numeros4)
# Out:
# {1: 10, 2: 20, 3: 30}

# %%
# Definición de un diicionario empleando cadenas como clave
estudiantes_c12 = {"nombre1":"Castro", 
                   "nombre2":"Jean Carlos",
                   "nombre3":"Renzo"}
print(estudiantes_c12)
# Out:
# {'nombre1': 'Castro', 'nombre2': 'Jean Carlos', 'nombre3': 'Renzo'}

# %%
# Crear un diccionario con tus nombres y apellido
# donde se usara como claves las cadenas "nombre", "apellido_p"
# y "apellido_m" 

nombre = {"nombre":"Jaime", 
          "apellido_p":"Garcia",  # corregir el apellido
          "apellido_m":"Marin"}   # agregar la clave y el valor para el DNI
print(nombre)

# Mostrar valor por clave o leer
print(nombre["nombre"]) # Imprime "Jaime"
print(nombre["apellido_p"])
print(nombre["apellido_m"])

# Sobreescribir un valor
nombre["apellido_p"]="Gomez" # Actualizar
print(nombre)

# Crear nuevo clave "DNI" con su valor
nombre["dni"]="123456789"
print(nombre)

# Crear nuevo clave "sexo"
nombre["sexo"]="M"
print(nombre)
# Out:
# {'nombre': 'Jaime', 'apellido_p': 'Garcia', 'apellido_m': 'Marin'}
# Jaime
# Garcia
# Marin
# {'nombre': 'Jaime', 'apellido_p': 'Gomez', 'apellido_m': 'Marin'}
# {'nombre': 'Jaime', 'apellido_p': 'Gomez', 'apellido_m': 'Marin', 'dni': '123456789'}
# {'nombre': 'Jaime', 'apellido_p': 'Gomez', 'apellido_m': 'Marin', 'dni': '123456789', 'sexo': 'M'}

# %% [markdown]
# A continuación mostraremos las diferentes propiedades de los "diccionarios"

# %% [markdown]
# # 2.- Propiedades

# %% [markdown]
# ### 2.1. Las "claves" en los diccionarios no se debe **repetir** porque generaria inconsistencias

# %%
# Sin claves repetidas
numeros = {1:10,2:20,3:30}
print(numeros)
# Con claves repetidas
numeros = {2:10,2:20,3:30}
print(numeros)
# Out:
# {1: 10, 2: 20, 3: 30}
# {2: 20, 3: 30}

# %%
# Sin claves repetidas usando cadenas
colores = {"color-01":"rojo", "color-02":"verde", "color-03":"amarillo"}
print(colores)

# Con claves repetidas usando cadenas
colores = {"color-01":"rojo", "color-01":"verde", "color-03":"amarillo"}
print(colores)
# Out:
# {'color-01': 'rojo', 'color-02': 'verde', 'color-03': 'amarillo'}
# {'color-01': 'verde', 'color-03': 'amarillo'}

# %%
# Ejercicio 1 : crear un diccionario con las clave 1, 2, 3 y como contenido
# los valores "uno", "dos" y "tres"

# %%
# Ejercicio 2 : crear un diccionario que tenga como clave los dias de la semana
# "lunes", "martes", "miercoles", "jueves" y "viernes". Como datos tendra los números
# 1, 2, 3, 4 y 5 respectivamente.

# %% [markdown]
# ### 2.2. Los diccionarios solo puede tener como claves valores booleanos, enteros, decimales y cadenas. No se permite otro tipo de datos

# %%
# Tiene como clave números booleanos
estados = {True:"SI",False:"NO"} 
print(estados)

# Tiene como clave números enteros
numeros = {1:10,2:20,3:20} 
print(numeros)

# Tiene como clave números decimales
decimales = {1.2:10,1.3:20,1.4:20} 
print(decimales)

# Tiene como clave cadenas
colores = {"rojo":1, "verde":2, "amarillo":3} 
print(colores)

# Tiene como claves tipos distintos
mixto = {True:"booleano",2:"entero", 4.5:"decimal","nombre":"cadena"}
print(mixto)
# Out:
# {True: 'SI', False: 'NO'}
# {1: 10, 2: 20, 3: 20}
# {1.2: 10, 1.3: 20, 1.4: 20}
# {'rojo': 1, 'verde': 2, 'amarillo': 3}
# {True: 'booleano', 2: 'entero', 4.5: 'decimal', 'nombre': 'cadena'}

# %%
# Ejercicio 3: Se tiene la siguientes notas de un curso :
# 12, 14, 15, 16, 18, 12, 14, 13, 10, 19
#·Se requiere generar un diccionario que tenga como 
# clave la nota y como valor el números de veces 
# que la nota se repite
notas={10:1,12:2,13:1,14:2,15:1,16:1,18:1,19:1}
print(notas)
# Out:
# {10: 1, 12: 2, 13: 1, 14: 2, 15: 1, 16: 1, 18: 1, 19: 1}

# %% [markdown]
# ### 2.3.- En los diccionarios, los datos pueden ser accedido a traves de sus claves

# %%
# Tiene como clave números booleanos
estados = {True:"SI",False:"NO"} 
print(estados[True])  # accedo al daot con clave True
# Out:
# SI

# %%
# Tiene como clave números enteros
numeros = {1:10,2:20,3:20} 
print(numeros[2])    # accedo al dato con clave 2
# Out:
# 20

# %%
# Tiene como clave números decimales
decimales = {1.2:10,1.2:21,1.3:22} 
print(decimales[1.3])     # accedo al dato con clave 1,3
# Out:
# 22

# %%
# Tiene como clave cadenas
colores = {"rojo":1, "verde":2, "amarillo":3} 
print(colores["verde"])     # accedo al dato con clave "verde"
# Out:
# 2

# %%
# Tiene como claves tipos distintos
mixto = {True:"booleano",2:"entero", 4.5:"decimal","nombre":"cadena"}
print(mixto[4.5])       # accedo al dato con la clave 4.5
# Out:
# decimal

# %% [markdown]
# **Ejercicio 4**: Se tiene la venta de smarphone de Q1 del 2020 [Referencia](https://www.strategyanalytics.com/strategy-analytics/blogs/devices/smartphones/smart-phones/2020/04/30/global-smartphone-shipments-fall-17-percent-in-q1-2020)
#
# | Marca | Unidades vendidas (millones) |
# |-|:-:|
# | Samsung | 58.3 |
# |Huawei|48.5|
# |Apple|39.2|
# |Xiaomi|27.5|
# |OPPO|22.6|
# |Others|78.7|
#
# Se debe implementar un diccionario que emplee con clave los nombres de las marcar. Debera cálcular la suma de las ventas de smartphone de Xiaomi y Huawei

# %%
# Escribir la solución del ejercicio

# %% [markdown]
# ### 2.4.- En los diccionarios, se puede agregar o sobreescribir un registro a través de una clave, se usa la siguiente notación :
# $$ diccionario[clave] = valor $$

# %%
mis_promedios  = {"matematica":14,
                  "lenguaje":16}
print(mis_promedios)

# Agrego el promedio de "programación"
mis_promedios["programacion"]= 17
print(mis_promedios)

# Modifico el promedio de "matematica"
mis_promedios["matematica"]= 13
print(mis_promedios)

# %% [markdown]
# ### 2.5.- Los diccionarios permiten tener en sus datos tuplas, listas , set o diccionarios, es decir pueden tener un almacenamiento anidado

# %%
# Diccionario con listas anidadas
mis_notas   = {"matematica":[14,15,18,15],  
               "lenguaje":[20,18,15,14],
               "programacion":[13,11,10,15],}
#print(mis_notas)

# Mostra la primera nota de Lenguaje
print(mis_notas["lenguaje"][0])

# ¿Cuál es la 4ta nota de programación"?
print(mis_notas["programacion"][3])

# ¿Cuál es el promedio de las notas de lenguaje?"
print(sum(mis_notas["lenguaje"])/len(mis_notas["lenguaje"]))

#notas_lenguaje = mis_notas["lenguaje"]
#print(notas_lenguaje)
# Out:
# 20
# 15
# 16.75

# %%
# Diccionario con diccionarios anidados
alumnos   = {"COD-01": {"nombre":"Jaime","apellido":"Gomez"},                          
             "COD-02": {"nombre":"Noemi","apellido":"Hernandez"},                                       
             "COD-03": {"nombre":"Julio","apellido":"Cesar"} }
#print(alumnos)

# Mostra el apellido del alumno con codigo "COD-02"
print(alumnos["COD-02"]["apellido"])
# Out:
# Hernandez

# %% [markdown]
# # 3.- Funciones
# Las Listas tiene funciones básicas que nos permiten realizar tareas concretas

# %% [markdown]
# ## len()
# Retorna el tamaño de un "set"

# %%
estudiantes = {1:"Juan",2: "Maria", 3:"ALberto",4:"Maribel",5: "Inmaculada"}
nro_estudiantes = len(estudiantes)
print(nro_estudiantes)
#print('El número  de estudiantes es = {}'.format(nro_estudiantes))

# %% [markdown]
# ## update()
#
# Permite agregar un diccionario a otro diccionario

# %%
# Diccionario unido a otro diccionario
colores = {1:"red", 3:"green", 5:"yellow", 7:"blue"}
nuevos_colores = {2:"white", 4:"black", 6:"purple"} # Es un set

#colores = colores + nuevos_colores # Esto da un error
colores.update(nuevos_colores)
print("colores :", colores)
# Out:
# colores : {1: 'red', 3: 'green', 5: 'yellow', 7: 'blue', 2: 'white', 4: 'black', 6: 'purple'}

# %%
# Ejercicio 6 : Se tiene un diccionario con los dias de la semana:
#                1:"lunes", 2:"martes" y 3:"miercoles"
# En otro diccionario se tiene los otros  dias de la semana
#                4:"jueves" y 5:"viernes"
# Unificar los dos diccionario en el primer diccionario

# %% [markdown]
# ## pop(clave)
#
# Remueve un registro del diccionario por la clave y devuelve el valor del registro. En caso de no existir la clave da una excepción.

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

valor = mis_notas.pop("lenguaje") # remueve un registro por la clave
print("Valor leido {}".format(valor))

print(mis_notas)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Valor leido 15
# {'matematica': 16, 'ingles': 17}

# %% [markdown]
# ## get(clave)
#
# Lee el valor de un registro del diccionario por la clave y devuelve el valor del registro, no elimina el registro. En caso de no existir la clave devuelve como valor **None**
#
# $$ diccionario[clave]$$

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

valor = mis_notas.get("lenguaje") # Lee un valor a través de una clave
print("Valor leido {}".format(valor))
print(mis_notas)

valor = mis_notas.get("programacion") # Lee un valor a través de una clave que no existe
print("Valor leido {}".format(valor))
print(mis_notas)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Valor leido 15
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Valor leido None
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}

# %% [markdown]
# Se recomienda com alternativa, leer el valor de un registro del diccionario de la siguiente manera
#
# $$ diccionario[clave]$$
#
# Tener en cuenta que si la clave no existe, da una excepción

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

valor = mis_notas["lenguaje"] # Lee un valor a través de una clave
print("Valor leido {}".format(valor))
print(mis_notas)

#valor = mis_notas["programacion"] # Lee un valor a través de una clave que no existe
#print("Valor leido {}".format(valor))
#print(mis_notas)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Valor leido 15
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}

# %% [markdown]
# ## in
# Permite saber si una clave esta presente en un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

# ¿La nota de "programacion" esta en mis_notas?
esta_programacion = "programacion" in mis_notas
print(esta_programacion)

# ¿La nota de "lenguaje" esta en mis_notas?
esta_lenguaje = "lenguaje" in mis_notas
print(esta_lenguaje)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# False
# True

# %% [markdown]
# ## sorted()
# Permite ordenar las claves de un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

# Ordena las claves de un diccionario
print(sorted(mis_notas))

# Ordena las claves de un diccionario en forma descendente
print(sorted(mis_notas, reverse=True))
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# ['ingles', 'lenguaje', 'matematica']
# ['matematica', 'lenguaje', 'ingles']

# %% [markdown]
# ## keys()
# Obtiene las claves del diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

claves = mis_notas.keys()
print("Claves: {}".format(claves))
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Claves: dict_keys(['matematica', 'lenguaje', 'ingles'])

# %% [markdown]
# Otra forma de obtener las claves es a través de la función **list()**

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

claves = list(mis_notas)
print("Claves: {}".format(claves))

# %% [markdown]
# ## values()
# Obtiene los valores de un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

valores = mis_notas.values()
print("Valores:{}".format(valores))
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Valores:dict_values([16, 15, 17])

# %% [markdown]
# ## items()
# Obtiene los registros de un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

registros = mis_notas.items()
print("Registros ", registros)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# Registros  dict_items([('matematica', 16), ('lenguaje', 15), ('ingles', 17)])

# %% [markdown]
# ## clear()
# Elimina todos los registros de un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print(mis_notas)

mis_notas.clear() # remueve todos los registros
print(mis_notas)
# Out:
# {'matematica': 16, 'lenguaje': 15, 'ingles': 17}
# {}

# %% [markdown]
# ## copy()
# Hace una copia de un diccionario

# %%
mis_notas = {"matematica":16,"lenguaje":15,"ingles":17}
print("mis_notas =", mis_notas)

backup_mis_notas = mis_notas.copy() # hace una copia de respaldo
print("backup_datos =", backup_mis_notas)

print('Borra los registros de "mis_notas"')
mis_notas.clear()

print("mis_datos =", mis_notas)
print("backup_datos =", backup_mis_notas)

# %% [markdown]
# ## type()
#
# Permita saber el tipo de datos de una variable

# %%
mi_nro = 10
print(type(mi_nro)) 

mi_decimal = 10.4
print(type(mi_decimal)) 

es_martes = True
print(type(es_martes)) 

mi_nombre = "Jaime"
print(type(mi_nombre)) 

mi_tupla = ("JAIME","AAA","I","M","E",21,12.3,3)
print(type(mi_tupla)) 

mi_lista = ["JAIME","AAA","I","M","E",21,12.3,3]
print(type(mi_lista)) 

mi_set = {"JAIME","AAA","I","M","E",21,12.3,3}
print(type(mi_set)) 

mi_dicc = {"nombre":"Jaime",3:"martes", True:"Es positivo" }
print(type(mi_dicc))

# %% [markdown]
# # 4.-  Desafio
#
# A continuación se presenta los 10 smartphone más vendidos en el [Q1 del 2020](https://paidfreedroid.com/2020/05/top-10-most-popular-smartphones-in-the-world-q1-2020-report.html) ,
#
#
# |RANK|Model	|OEM	|Unit (Million)|
# |-:|-|:-:|-:|
# |1|	iPhone 11|	Apple	|19.5|
# |2|	Galaxy A51|	Samsung|	6.8|
# |3|	Redmi Note 8|	Xiaomi|	6.6|
# |4|	Redmi Note 8 Pro|	Xiaomi|	6.1|
# |5|	iPhone XR|	Apple|	4.7|
# |6|	iPhone 11 Pro Max|	Apple|	4.2|
# |7|	Galaxy A10s	|Samsung|	3.9|
# |8|	iPhone 11 Pro	|Apple|	3.8|
# |9|	Galaxy S20+ 5G	|Samsung|	3.5|
# |10|	Galaxy A30s	|Samsung|	3.4|
#
# Crear un diccionario anidado, donde la primera clave será la marca del smartphone y la subclave de los datos será el modelo del smarphone, para este último caso el valor será la cantidad de smartphone vendidos en el Q1 del 2020
#
# De acuerdo a lo mencionado, cálcular:
#
# - Números de smartphone vendidos por cada fabricante
# - Obtener los modelos de smarphone vendidos por Apple
# - Obtener la cantidad del smartphone vendidos del modelo Galaxy A10s

# %% [markdown]
# # 5.-  Conclusión
#
# - Los diccionarios nos permite almacenar datos organizados por claves
# - Con los diccioanrios podemos realizar búsquedas de registros por claves
# - Con los diccionarios podemos eliminar registros por clave

# %% [markdown]
# #Laboratorio

# %%
# Ejercicio 01
dic = [ 'a',
        'b',
        {'c': 1,
         'd': { 'x' : 10,
                'y' : 20,
                'z' : 30},
         'e': 3},
        'f',
        'g' ]

print(dic)
print(dic[2]['d']['z'])
# Out:
# ['a', 'b', {'c': 1, 'd': {'x': 10, 'y': 20, 'z': 30}, 'e': 3}, 'f', 'g']
# 30

# %%
# Ejercicio 02

#| ID | NOMBRE | APELLIDO | TELEFONO | ESTADO |
#---------------------------------------------------------
#| 1001 | Alexander | Diaz | 989856248 | activo |
#---------------------------------------------------------
#| 1002 | Raul | Mendoza | 989856242 | activo |
#---------------------------------------------------------
#| 1003 | Juan | Perez | 989856243 | activo |
#---------------------------------------------------------
#| 1004 | Carlos | Aponte | 989856244 | activo |
#---------------------------------------------------------
#| 1005 | Kevin | Cueva | 989856245 | activo |

poblacion = {1001:{"NOMBRE":"Alexander","APELLIDO":"Diaz"},  
             1002:{"NOMBRE":"Raul","APELLIDO":"Mendoza"} }
# Diccionario con diccionarios anidados
# alumnos   = {"COD-01": {"nombre":"Jaime","apellido":"Gomez"},                          
#              "COD-02": {"nombre":"Noemi","apellido":"Hernandez"},                                       
#              "COD-03": {"nombre":"Julio","apellido":"Cesar"} }


# ..... Mostrar todos los  registros
#print(poblacion)

for key, value in poblacion.items():
  print(key)
  print(value)

# ..... Agregar un registro

# ..... Modificar el apellido de un registro

print("ANTES : ", poblacion[1002])
poblacion[1002]["APELLIDO"] = "Gomez"
print("DESPUES : ", poblacion[1002])

# ..... Eliminar un registro

# ..... Buscar un registro por ID
# Out:
# 1001
# {'NOMBRE': 'Alexander', 'APELLIDO': 'Diaz'}
# 1002
# {'NOMBRE': 'Raul', 'APELLIDO': 'Mendoza'}
# ANTES :  {'NOMBRE': 'Raul', 'APELLIDO': 'Mendoza'}
# DESPUES :  {'NOMBRE': 'Raul', 'APELLIDO': 'Gomez'}

# %%
# a) Cree el diccionario Dic_SuApellidoPaterno  

#  Con los siguientes elementos: 
#           CODIGO     NOMBRE.   PRECIO 
#.           101     Toalla baño   35 
#            102     Toalla mano   15 
#            103     Toalla cara    6 

productos = {
              "101":{"Toalla baño",35},             
              "102":{"Toalla mano",15},            
              "103":{"Toalla cara",6}             
            }

print(productos["103"])
print(productos["101"])
print(productos["102"])


# b) Agregue  un  nuevo  elemento  utilizando  el método  apropiado,  
#       usted  defina  el  código, producto y precio. 
print("ANTES : " , productos)
productos["104"] = {"Toalla descartable",3} # Agrega un nuevo elemento
print("DESPUES : " , productos)

#  c)Imprima las llaves (o claves) de su diccionario. 

claves = productos.keys()
print("LAS CLAVES SON ", claves)

#. d)Utilizando métodos imprima solo el precio del producto 102. 
print(productos.get("102"))  # Usando el método get
print(productos["102"])      # Sin usar métodos
# Out:
# {'Toalla cara', 6}
# {'Toalla baño', 35}
# {'Toalla mano', 15}
# ANTES :  {'101': {'Toalla baño', 35}, '102': {'Toalla mano', 15}, '103': {'Toalla cara', 6}}
# DESPUES :  {'101': {'Toalla baño', 35}, '102': {'Toalla mano', 15}, '103': {'Toalla cara', 6}, '104': {3, 'Toalla descartable'}}
# LAS CLAVES SON  dict_keys(['101', '102', '103', '104'])
# {'Toalla mano', 15}
# {'Toalla mano', 15}
