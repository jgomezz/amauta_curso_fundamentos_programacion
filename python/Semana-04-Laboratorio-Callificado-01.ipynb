# %% [markdown]
# #Laboratorio Calificado 01
#
# ---
#
# - Apellidos y Nombre :
# - Especialidad :
# - Ciclo :
# - Sección :

# %% [markdown]
# ## Objetivos
# - Crear programas Python
# - Imprimir valores utilizando formato
# - Diferenciar tipos de datos y utilizar operadores aritméticos, de asignación y lógicos
# - Identificar y crear tuplas
#
# ## Equipos, materiales, programas y recursos:
# - Programa Python
# - Material adicional en Canvas TECSUP

# %% [markdown]
# ## Recomendaciones
#
# Cerrar todo programa que pueda distraerte de tu sesión virtual.
#
# - Eliminar distracciones
# - Realizar apuntes de la sesión virtual
# - Repetir los ejercicios realizados en la sesión virtual.

# %% [markdown]
# ## Procedimiento y Resultados
#
# El laboratorio calificado debe ser entregado como un archivo PDF, para tal fin seguir el siguiente procedimiento:
# - Seleccionar el menu **"Archivo"**
# - Escoger la opción **"Imprimir"** y grabar con **archivo PDF**
# - El archivo PDF generado en el paso anterior debera ser subido en la **tarea de Canvas**.

# %% [markdown]
# ## Desarrollo de la Práctica

# %% [markdown]
# ### Ejercicio *1*  (6 puntos)
#
# Escriba en Python un programa que imprima los datos que se muestran en la siguiente imagen
#
# <center>
# <img src="https://raw.githubusercontent.com/jgomezm-tecsup/curso-introduccion-programacion/master/_assets/lab-calificados-01-ejercicio-01.png" alt = "Factura" height = 200 title="Ejercicio 01">
# </center>
#
#
# - Reemplace el dato de cliente por su nombre y apellido paterno
# - Utilice alineaciones izquierda, centrada y derecha como se muestra en el modelo.
# - Los precios deben de mostrar dos decimales.

# %% [markdown]
# ### Ejercicio *2* (6 puntos)
#
# Escriba en Python un programa que calcule e imprima los resultados, considerando los valores de las variables a, b y c iguales a 4, 12 y 5 respectivamente:
# - Eleve el valor de c, a la potencia del valor de a.
# - Calcule la división entera de b entre c
# - Calcule el residuo de b entre c
# - Modifique el valor de a para que sea elevado al valor de c (use operadores de
# asignación)
# - Muestre el resultado de la comparación: a mayor c ó b mayor que c)

# %% [markdown]
# ### Ejercicio *3* (8 puntos)
# Escriba en Python un programa que cree las siguientes tuplas y las imprima respetando el formato de alineación que se muestra en la imagen (el nombre de cada tupla deberá de tener su apellido paterno, por ejemplo: melendez0
#
# <center>
# <img src="https://raw.githubusercontent.com/jgomezm-tecsup/curso-introduccion-programacion/master/_assets/lab-calificados-01-ejercicio-03.png" alt = "Tabla" height = 200 title="Ejercicio 03">
# </center>
#
# Además,
# - Averigüe cuantas veces se repite el número 20 en la segunda tupla.
# - Encuentre la posición del número 20 en la segunda tupla.

# %%
jgomez0 = ("Código","Nombre","Edad")
