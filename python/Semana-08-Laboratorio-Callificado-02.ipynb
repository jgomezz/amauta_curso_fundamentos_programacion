# %% [markdown]
# #Laboratorio Calificado 02
#
# ---
#
# - Apellidos y Nombre :
# - Especialidad :
# - Ciclo :
# - Sección :

# %% [markdown]
# ## Objetivos
# - Crear programas Python
# - Imprimir valores utilizando formato
# - Diferenciar tipos de datos y utilizar operadores aritméticos, de asignación y lógicos
# - Identificar y crear tuplas
#
# ## Equipos, materiales, programas y recursos:
# - Programa Python
# - Material adicional en Canvas TECSUP

# %% [markdown]
# ## Recomendaciones
#
# Cerrar todo programa que pueda distraerte de tu sesión virtual.
#
# - Eliminar distracciones
# - Realizar apuntes de la sesión virtual
# - Repetir los ejercicios realizados en la sesión virtual.

# %% [markdown]
# ## Procedimiento y Resultados
#
# El laboratorio calificado debe ser entregado como un archivo PDF, para tal fin seguir el siguiente procedimiento:
# - Seleccionar el menu **"Archivo"**
# - Escoger la opción **"Imprimir"** y grabar con **archivo PDF**
# - El archivo PDF generado en el paso anterior debera ser subido en la **tarea de Canvas**.

# %% [markdown]
# ## Desarrollo de la Práctica

# %% [markdown]
# ### Ejercicio *1*  (10 puntos)
#
# a) Cree la lista que contenga los siguientes elementos (el nombre de su lista será lista_SuApellidoPaterno, ejm lista_perez)
#    - Lápiz
#    - Borrador
#    - Tajador
#    - Lapicero
#
# b) Utilice el método apropiado para agregar los elementos Cuaderno y Regla a su lista.
#
# c) Utilice el método apropiado para eliminar el elemento Borrador
#
# d) Utilizando Slicing imprima del elemento 2 al elemento 4 ( Borrador, Tajador  y Lapicero)
#
# e) Imprima todos los elementos de su lista.

# %% [markdown]
# ### Ejercicio *2* (10 puntos)
#
# a) Cree los conjuntos:
#  - A : teclado, mouse, cámara
#  - B : impresora, pantalla, parlantes
#  - C : cpu, pantalla, teclado, mouse
#  - D : conjunto vacío
#
# b) Utilizando el método apropiado agregue el elemento memoria al conjunto C
#
# c) Utilice el método u operador apropiado para que el conjunto D contenga todos los elementos de A, B y C.
#
# d) Imprima la intersección de los elementos A y C
#
# e) Utilizando métodos averigüe si el conjunto D es subconjunto de B, imprima el resultado.
